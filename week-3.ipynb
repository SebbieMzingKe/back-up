# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
results = pd.read_csv(r"C:\Users\Sebbie\Downloads\KL_DB\results.csv")
results
# Out:
# C:\Users\Sebbie\AppData\Local\Temp\ipykernel_4528\3785456021.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   results = pd.read_csv(r"C:\Users\Sebbie\Downloads\KL_DB\results.csv")
#                        Games                          Event             Team  \
# 0       1912 Summer Olympics         Singles, Men (Olympic)              NaN
# 1       1912 Summer Olympics         Doubles, Men (Olympic)   Jean Montariol
# 2       1920 Summer Olympics         Singles, Men (Olympic)              NaN
# 3       1920 Summer Olympics       Doubles, Mixed (Olympic)  Jeanne Vaussard
# 4       1920 Summer Olympics         Doubles, Men (Olympic)  Jacques Brugnon
# ...                      ...                            ...              ...
# 308403  2022 Winter Olympics         Singles, Men (Olympic)              NaN
# 308404  2022 Winter Olympics        Slalom, Women (Olympic)              NaN
# ...

# %%
bios = pd.read_csv(r"C:\Users\Sebbie\Downloads\KL_DB\bios.csv")
bios
# Out:
#                                             Roles     Sex  \
# 0                       Competed in Olympic Games    Male
# 1                       Competed in Olympic Games    Male
# 2       Competed in Olympic Games • Administrator    Male
# 3                       Competed in Olympic Games    Male
# 4                       Competed in Olympic Games    Male
# ...                                           ...     ...
# 145495                  Competed in Olympic Games  Female
# 145496                  Competed in Olympic Games  Female
# 145497                  Competed in Olympic Games  Female
# 145498                  Competed in Olympic Games    Male
# 145499                Non-starter • Administrator    Male
#
#                                                 Full name  \
# 0       François Joseph Marie Antoine "Jean-François"•...
# 1                                 Arnaud Benjamin•Boetsch
# 2                             Jean Laurent Robert•Borotra
# ...

# %%
df = pd.DataFrame(
    {
        'A': [6, 7, 8, 9, 0],
        'B': [1, 2, 3, 4, 5],
        "C": ["a", "b", "c", "d", "e"]
    }
)

# %%
df
# Out:
#    A  B  C
# 0  6  1  a
# 1  7  2  b
# 2  8  3  c
# 3  9  4  d
# 4  0  5  e

# %%
df1 = pd.read_csv(r"C:\Users\Sebbie\Downloads\KL_DB\advertising.csv")
df1
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]
